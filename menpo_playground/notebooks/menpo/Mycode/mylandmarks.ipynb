# %%
# %matplotlib inline
import os
import menpo.io as mio
from menpo.landmark import labeller, face_ibug_68_to_face_ibug_68


image_dir = "/Users/Lee/Desktop/Menpo_Playground_With_Mynotes/menpo_playground/mycode/BingBangTheory.jpg"
print( image_dir )

bigbang = mio.import_image( image_dir )
has_landmarks = bigbang.has_landmarks

labeller( bigbang, 'PTS', face_ibug_68_to_face_ibug_68 )
    
print( "Does BigBang has landmarks? -{}".format( bigbang.has_landmarks ) )

print('What labels do these groups have?')
for g in bigbang.landmarks:
    print(' - {}'.format(g))

print('ibug_face_68 semantic labels are?')
for l in bigbang.landmarks['face_ibug_68']:
    print(' - {}'.format(l))
# Out:
# /Users/Lee/Desktop/Menpo_Playground_With_Mynotes/menpo_playground/mycode/BingBangTheory.jpg
# Does BigBang has landmarks? -True
# What labels do these groups have?
#  - face_ibug_68
#  - PTS
# ibug_face_68 semantic labels are?
#  - jaw
#  - left_eyebrow
#  - right_eyebrow
#  - nose
#  - left_eye
#  - right_eye
#  - mouth

# %%
bigbang.view_widget( );

# %%
bigbang.landmarks['face_ibug_68'].view();
